# %%
# %pip --quiet install --upgrade neo4j langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Neo4j setup

# %%
# from langchain_community.graphs import Neo4jGraph
from langchain_neo4j import Neo4jGraph
from dotenv import load_dotenv
import os
# from langchain.graphs.neo4j_graph import Neo4jGraph 
# from langchain.chains import GraphQAChain old
from langchain_neo4j import GraphCypherQAChain

from langchain_core.prompts import PromptTemplate
# from langchain_community.chains.graph_qa.cypher import GraphCypherQAChain

load_dotenv()
neo_pass = os.getenv("NEO4J_PASS")
neo_db_id = os.getenv("DB_ID")

graph = Neo4jGraph(
    url="neo4j+s://f5c81351.databases.neo4j.io",
    username="neo4j",
    password=neo_pass,
    enhanced_schema=True
    # refresh_schema=Fa lse
)

def clean_graph():
    query = """
    MATCH (n)
    DETACH DELETE n
    """
    graph.query(query)

# %% [markdown]
# ### OpenAI setup

# %%
import getpass
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
# os.environ[api_key] = getpass.getpass()
import os
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Neo4jVector

llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")

additional_instructions = """
When creating entities, add a "document_id" property to each node and set it to the document's unique ID.
For example, if the document ID is "doc123", each created node should include document_id: "doc123".
Query example: 
CREATE (n:NodeLabel) 
SET n.document_id = "doc123" 
RETURN n
"""
llm_transformer = LLMGraphTransformer(llm=llm, additional_instructions=additional_instructions, ignore_tool_usage=True)

# Embeddings for complex search queries
embed = OpenAIEmbeddings(model="text-embedding-ada-002")
vector_index = Neo4jVector.from_existing_graph(
    embedding=embed,
    search_type="vector",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)
vector_retriever = vector_index.as_retriever()

# %% [markdown]
# ### Split document into chunks

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

pdf_path = "resume2.pdf"
loader = PyPDFLoader(pdf_path)
pages = loader.load_and_split()
pages = loader.load() # load pages

# chunk overlap is the shared context window between chunks--allows context to be maintained across chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200, length_function=len)

splits = text_splitter.split_documents(pages) # split the pages using LangChain's text_splitter

processed_chunks = []

for i, chunk in enumerate(splits):
    # Process the chunk
    metadata = {
        "chunk_id": i,
        "source": pdf_path,
        "page_number": chunk.metadata.get("page", None),
        "total_length": len(chunk.page_content),
        "text_preview": (
            chunk.page_content[:100] + "..."
            if len(chunk.page_content) > 100
                else chunk.page_content
        ),


    }
    # Store the metadata for each chunk after processing
    processed_chunks.append({"text": chunk.page_content, "metadata": metadata})

print(str(len(processed_chunks)) + " chunks processed")
# print(processed_chunks[6]['metadata']['text_preview'])
# print(processed_chunks[6]['metadata'])
# print(processed_chunks[0]['text_preview'])
# Out:
# 5 chunks processed

# %%
# Check out processed chunks
print(processed_chunks[3])
print(processed_chunks[4])
# Out:
# {'text': "• Spearheadedourmarketing(grewviewcountto44.8k),sponsorship(raised$54K),anddevstrategies(2023site&livesite).\nLulaTechnologies(Startup) Miami,FL,USA\nContract April2023-April2023\n• RewrotesectionsofthenewLulaSafeAPIserviceforLula,aninsuranceinfrastructurestartupthathasraisedoverUSD\n$18MinfundingfromnotableinvestorssuchasBillAckman,AndrewWilkinson,StevePagliuca,BainCapital,andothers.\n• Wrotethequickstart,runcheck,andPHPguides(PHP/Postman/TypeScript/GraphQL/REST/ReadMeDocs).\nBookin(ASimpleAirbnbClone-FullStackApplication)| github.com/Deniz-Jasa/Bookin\n• Features:Dynamicpropertylisting,userproﬁles,searchﬁlters,customer&hostview,andareservationsystem(React).\n• ImprovedscalabilityandsecuritybyhandlingdataviaAPIendpoints(next.js)anddeployingourdatabaseonAWSRDS.\nEducation\nUniversityofOttawa September2021-December2025\nBachelor's,ComputerScience GPA:3.8/4.0\n• RelevantCoursework:Python,Java,C++,DataStructures&Algorithms,Databases,Networking,&ComputerArchitecture.", 'metadata': {'chunk_id': 3, 'source': 'resume2.pdf', 'page_number': 0, 'total_length': 965, 'text_preview': '• Spearheadedourmarketing(grewviewcountto44.8k),sponsorship(raised$54K),anddevstrategies(2023site&li...'}}
# {'text': "UniversityofOttawa September2021-December2025\nBachelor's,ComputerScience GPA:3.8/4.0\n• RelevantCoursework:Python,Java,C++,DataStructures&Algorithms,Databases,Networking,&ComputerArchitecture.\n• ActivitiesandSocieties:uOttaHack,TeachingAssistant(Python101),VPEquityofIEEEuOttawa,andMen'sBasketball.", 'metadata': {'chunk_id': 4, 'source': 'resume2.pdf', 'page_number': 0, 'total_length': 297, 'text_preview': "UniversityofOttawa September2021-December2025\nBachelor's,ComputerScience GPA:3.8/4.0\n• RelevantCours..."}}

# %% [markdown]
# ### Parse Document (prob able to optimize this)

# %%
import asyncio
from langchain_core.documents import Document


# Convert processed chunks to Langchain Document for Neo4j db
docs = [
    Document(
        page_content=chunk['text'],
        metadata=chunk['metadata']
    )
    for chunk in processed_chunks
]

# Function to process documents in batches
async def process_batches(docs, batch_size=2, retry_delay=20, max_retries=5):
    for i in range(0, len(docs), batch_size):
        batch = docs[i : i + batch_size] # Use subset of documents
        retries = 0
        
        while retries < max_retries:
            try:
                # generate embeddings for each doc
                for doc in batch:
                    embedding = embed.embed_query(doc.page_content)
                    doc.metadata["embedding"] = embedding


                graph_docs = await llm_transformer.aconvert_to_graph_documents(batch)
                print(f"Processed batch {i // batch_size + 1}: {graph_docs}")
                
                # Add to Neo4j
                graph.add_graph_documents(graph_docs, include_source=True, baseEntityLabel=True)
                print(f"Successfully added batch {i // batch_size + 1} to Neo4j")
                break  # exit if retry works
            
            except Exception as e:
                if "rate_limit_exceeded" in str(e):
                    retries += 1
                    print(f"Rate limit hit. Retrying batch {i // batch_size + 1} in {retry_delay} seconds... (Attempt {retries}/{max_retries})")
                    await asyncio.sleep(retry_delay)
                else:
                    raise  # other error

# Run batching process
await process_batches(docs, batch_size=2)
# Out:
# Processed batch 1: [GraphDocument(nodes=[Node(id='AWS', type='Technology', properties={}), Node(id='React.js', type='Technology', properties={}), Node(id='Created a reverse proxy solution to allow direct access to a cloud instance speeding up frontend development (Nginx, EC2)', type='Project', properties={}), Node(id='github.com/Deniz-Jasa', type='Social Media', properties={}), Node(id='+1 873-354-9180', type='Contact', properties={}), Node(id='R', type='Language', properties={}), Node(id='REST', type='Technology', properties={}), Node(id='C', type='Language', properties={}), Node(id='Nginx', type='Technology', properties={}), Node(id='Developed a lambda that can be called on-demand that executed REST service calls for testing (REST, Python, AWS)', type='Project', properties={}), Node(id='C++', type='Language', properties={}), Node(id='TypeScript', type='Language', properties={}), Node(id='Git', type='Technology', properties={}), Node(id='Node', type='Technology', properties={}), Node(id='Go', type='Language', properties={}), Node(id='PHP', type='Language', properties={}), Node(id='linkedin.com/in/deniz-jasarbasic', type='Social Media', properties={}), Node(id='Stripe', type='Technology', properties={}), Node(id='Kotlin', type='Language', properties={}), Node(id='DENIZJASARBASIC', type='Person', properties={}), Node(id='Bash', type='Language', properties={}), Node(id='Added new pipeline jobs in the back-end to handle various EC2 management needs for DevOps (Python/Docker/AWS)', type='Project', properties={}), Node(id='GraphQL', type='Technology', properties={}), Node(id='Revamped the UI/UX from scratch of an internal DevOps tool which wraps around Jenkins, empowering various groups within Apple to more easily execute CI/CD pipeline jobs, speeding up infrastructure management by 36% (React/Figma)', type='Project', properties={}), Node(id='Jenkins', type='Technology', properties={}), Node(id='Ottawa, ON, Canada', type='Location', properties={}), Node(id='SQL', type='Language', properties={}), Node(id='JavaScript', type='Language', properties={}), Node(id='Apple', type='Company', properties={}), Node(id='Linux', type='Technology', properties={}), Node(id='Java', type='Language', properties={}), Node(id='Docker', type='Technology', properties={}), Node(id='Cupertino, CA, USA', type='Location', properties={}), Node(id='CSS', type='Language', properties={}), Node(id='Python', type='Language', properties={}), Node(id='OpenText', type='Company', properties={}), Node(id='denizjasarbasic1@gmail.com', type='Contact', properties={}), Node(id='Cloudflare', type='Technology', properties={}), Node(id='Angular', type='Technology', properties={}), Node(id='PostgreSQL', type='Technology', properties={}), Node(id='HTML', type='Language', properties={})], relationships=[Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Node(id='+1 873-354-9180', type='Contact', properties={}), type='HAS_PHONE_NUMBER', properties={}), Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Node(id='denizjasarbasic1@gmail.com', type='Contact', properties={}), type='HAS_EMAIL', properties={}), Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Node(id='linkedin.com/in/deniz-jasarbasic', type='Social Media', properties={}), type='HAS_LINKEDIN', properties={}), Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Node(id='github.com/Deniz-Jasa', type='Social Media', properties={}), type='HAS_GITHUB', properties={}), Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Node(id='Python', type='Language', properties={}), type='HAS_SKILL', properties={}), Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Node(id='TypeScript', type='Language', properties={}), type='HAS_SKILL', properties={}), Relationship(source=Node(id='DENIZJASARBASIC', type='Person', properties={}), target=Nod ...
# Successfully added batch 1 to Neo4j
# Processed batch 2: [GraphDocument(nodes=[Node(id='Python/BS4', type='Tool', properties={}), Node(id='REST', type='Service', properties={}), Node(id='DevelopedfromscratchaJava/Spring/RESTprojecttoaddressXSSvulnerabilitiesinsevenmajorAPIservices', type='Product', properties={}), Node(id='XSS', type='Vulnerability', properties={}), Node(id='Implementedamodalcomponentfordownloadingandviewingtext-baseddocumentswithinthebrowser', type='Product', properties={}), Node(id='React', type='Framework', properties={}), Node(id='Developedapipelinetoautomatethepushing,inserting,andmanipulationofthedataaboveintotablesanddatabases', type='Product', properties={}), Node(id='InternationalExperienceScholarship', type='Scholarship', properties={}), Node(id='Monterrey,NL,Mexico', type='Location', properties={}), Node(id='99%', type='Percentage', properties={}), Node(id='Scraped,collected,andcleansedcloseto6,000diﬀerentﬁnancialcompanydatapoints,historicaldatapoints,andstockmetricsacrosstheNASDAQ&NYSE', type='Activity', properties={}), Node(id='Ottawa,ON,Canada', type='Location', properties={}), Node(id='Python/PostgreSQL', type='Tool', properties={}), Node(id='Marketsheets', type='Company', properties={}), Node(id='Developedalambdathatcanbecalledon-demandthatexecutedRESTservicecallsfortesting', type='Product', properties={}), Node(id='AWS', type='Service', properties={}), Node(id='Python', type='Language', properties={}), Node(id='OpenText', type='Company', properties={})], relationships=[Relationship(source=Node(id='Developedalambdathatcanbecalledon-demandthatexecutedRESTservicecallsfortesting', type='Product', properties={}), target=Node(id='REST', type='Service', properties={}), type='EXECUTED_FOR', properties={}), Relationship(source=Node(id='Developedalambdathatcanbecalledon-demandthatexecutedRESTservicecallsfortesting', type='Product', properties={}), target=Node(id='Python', type='Language', properties={}), type='EXECUTED_FOR', properties={}), Relationship(source=Node(id='Developedalambdathatcanbecalledon-demandthatexecutedRESTservicecallsfortesting', type='Product', properties={}), target=Node(id='AWS', type='Service', properties={}), type='EXECUTED_FOR', properties={}), Relationship(source=Node(id='OpenText', type='Company', properties={}), target=Node(id='Ottawa,ON,Canada', type='Location', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='DevelopedfromscratchaJava/Spring/RESTprojecttoaddressXSSvulnerabilitiesinsevenmajorAPIservices', type='Product', properties={}), target=Node(id='XSS', type='Vulnerability', properties={}), type='ADDRESSED_VULNERABILITIES', properties={}), Relationship(source=Node(id='DevelopedfromscratchaJava/Spring/RESTprojecttoaddressXSSvulnerabilitiesinsevenmajorAPIservices', type='Product', properties={}), target=Node(id='99%', type='Percentage', properties={}), type='ACHIEVED_RISK_COVERAGE', properties={}), Relationship(source=Node(id='Implementedamodalcomponentfordownloadingandviewingtext-baseddocumentswithinthebrowser', type='Product', properties={}), target=Node(id='React', type='Framework', properties={}), type='IMPLEMENTED_FOR', properties={}), Relationship(source=Node(id='Marketsheets', type='Company', properties={}), target=Node(id='Ottawa,ON,Canada', type='Location', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='Scraped,collected,andcleansedcloseto6,000diﬀerentﬁnancialcompanydatapoints,historicaldatapoints,andstockmetricsacrosstheNASDAQ&NYSE', type='Activity', properties={}), target=Node(id='Python/BS4', type='Tool', properties={}), type='INVOLVED_IN', properties={}), Relationship(source=Node(id='Developedapipelinetoautomatethepushing,inserting,andmanipulationofthedataaboveintotablesanddatabases', type='Product', properties={}), target=Node(id='Python/PostgreSQL', type='Tool', properties={}), type='AUTOMATED', properties={}), Relationship(source=Node(id='InternationalExperienceScholarship', type='Scholarship', properties={}), target=Node(id='Mont ...
# Successfully added batch 2 to Neo4j
# Processed batch 3: [GraphDocument(nodes=[Node(id='500 students', type='Participants', properties={}), Node(id='Ottawa, ON, Canada', type='Location', properties={}), Node(id='25 companies', type='Participants', properties={}), Node(id='30 mentors', type='Participants', properties={}), Node(id='University of Ottawa', type='Organization', properties={}), Node(id='Dean of Engineering', type='Position', properties={}), Node(id='uottahack.ca', type='Website', properties={}), Node(id='Ottawa', type='City', properties={}), Node(id='uOttaHack', type='Event', properties={})], relationships=[Relationship(source=Node(id='University of Ottawa', type='Organization', properties={}), target=Node(id='uOttaHack', type='Event', properties={}), type='HOSTS', properties={}), Relationship(source=Node(id='University of Ottawa', type='Organization', properties={}), target=Node(id='Dean of Engineering', type='Position', properties={}), type='AWARDED_BY', properties={}), Relationship(source=Node(id='University of Ottawa', type='Organization', properties={}), target=Node(id='Ottawa', type='City', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='Ottawa', type='City', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='University of Ottawa', type='Organization', properties={}), type='ORGANIZED_BY', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='500 students', type='Participants', properties={}), type='HAS_PARTICIPANTS', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='30 mentors', type='Participants', properties={}), type='HAS_PARTICIPANTS', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='25 companies', type='Participants', properties={}), type='HAS_PARTICIPANTS', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='uottahack.ca', type='Website', properties={}), type='HAS_WEBSITE', properties={}), Relationship(source=Node(id='uOttaHack', type='Event', properties={}), target=Node(id='Ottawa, ON, Canada', type='Location', properties={}), type='HAS_LOCATION', properties={})], source=Document(metadata={'chunk_id': 2, 'source': 'resume2.pdf', 'page_number': 0, 'total_length': 994, 'text_preview': '(Python/PostgreSQL)thatcanbeeasilysearchedbycustomersfortheirmarketresearchintheMarkesheetsweb-app.\n...', 'embedding': [-0.003447915893048048, -0.019247865304350853, -0.006780661642551422, -0.04284341633319855, -0.00931441131979227, 0.027727290987968445, -0.020226813852787018, 0.0038942014798521996, -0.03840935230255127, -0.024632085114717484, 0.02044275775551796, -0.00839304830878973, 0.004711192101240158, -0.003615272929891944, 0.0038150218315422535, -0.003915796056389809, 0.022746168076992035, -0.03803504630923271, 0.0007747013587504625, -0.012870299629867077, -0.028562277555465698, -0.00898329634219408, -0.005218661855906248, 0.0032535658683627844, 0.0004487599362619221, -0.0022188310977071524, 0.006265993230044842, -0.031383953988552094, -0.004074155353009701, -0.02386908046901226, 0.011293903924524784, 0.00983267929404974, -0.01711721159517765, -0.0012992668198421597, -0.028950976207852364, -0.027799272909760475, 0.015763958916068077, -0.014396308921277523, 0.011999323032796383, 0.01507293526083231, 0.009587941691279411, 0.026114903390407562, 0.0012245860416442156, -0.007874781265854836, -0.01500095333904028, 0.014856990426778793, -0.004632012452930212, -0.04408149793744087, 0.005024311598390341, 0.03095206432044506, -0.0034605127293616533, 0.04105827212333679, -0.018945543095469475, 0.017793837934732437, 0.0045564319007098675, -0.01383485272526741, -0.011142742820084095, 0.01641179248690605, -4.5635173592017964e-05, 0.0027856857050210238, 0.01652696169912815, 0.014489884488284 ...
# Successfully added batch 3 to Neo4j
# Processed batch 4: [GraphDocument(nodes=[Node(id='Bain Capital', type='Investor', properties={}), Node(id='Bookin (A Simple Airbnb Clone - Full Stack Application)', type='Application', properties={}), Node(id='C++', type='Course', properties={}), Node(id='University of Ottawa', type='University', properties={}), Node(id='AWS RDS', type='Service', properties={}), Node(id='User profiles', type='Feature', properties={}), Node(id='Search filters', type='Feature', properties={}), Node(id="Bachelor's", type='Degree', properties={}), Node(id='Dynamic property listing', type='Feature', properties={}), Node(id='3.8/4.0', type='Grade', properties={}), Node(id='Miami, FL, USA', type='Location', properties={}), Node(id='Databases', type='Course', properties={}), Node(id='Bill Ackman', type='Investor', properties={}), Node(id='Andrew Wilkinson', type='Investor', properties={}), Node(id='Handling data via API endpoints (next.js)', type='Improvement', properties={}), Node(id='Data Structures & Algorithms', type='Course', properties={}), Node(id='github.com/Deniz-Jasa/Bookin', type='Website', properties={}), Node(id='Java', type='Course', properties={}), Node(id='April 2023 - April 2023', type='Contract', properties={}), Node(id='Python', type='Course', properties={}), Node(id='Computer Science', type='Field of Study', properties={}), Node(id='Customer & host view', type='Feature', properties={}), Node(id='Computer Architecture', type='Course', properties={}), Node(id='Networking', type='Course', properties={}), Node(id='Lula Technologies', type='Company', properties={}), Node(id='Reservations system', type='Feature', properties={}), Node(id='USD $18M', type='Funding', properties={}), Node(id='September 2021 - December 2025', type='Duration', properties={}), Node(id='LulaSafe API service', type='Service', properties={}), Node(id='Steve Pagliuca', type='Investor', properties={})], relationships=[Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='Miami, FL, USA', type='Location', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='April 2023 - April 2023', type='Contract', properties={}), type='HAS_CONTRACT', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='LulaSafe API service', type='Service', properties={}), type='DEVELOPED', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='USD $18M', type='Funding', properties={}), type='RAISED_FUNDS', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='Bill Ackman', type='Investor', properties={}), type='INVESTED_BY', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='Andrew Wilkinson', type='Investor', properties={}), type='INVESTED_BY', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='Steve Pagliuca', type='Investor', properties={}), type='INVESTED_BY', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='Bain Capital', type='Investor', properties={}), type='INVESTED_BY', properties={}), Relationship(source=Node(id='Lula Technologies', type='Company', properties={}), target=Node(id='Bookin (A Simple Airbnb Clone - Full Stack Application)', type='Application', properties={}), type='DEVELOPED', properties={}), Relationship(source=Node(id='Bookin (A Simple Airbnb Clone - Full Stack Application)', type='Application', properties={}), target=Node(id='github.com/Deniz-Jasa/Bookin', type='Website', properties={}), type='HOSTED_ON', properties={}), Relationship(source=Node(id='Bookin (A Simple Airbnb Clone - Full Stack Application)', type='Application', properties={}), target=Node(id='Dynamic property list ...
# Successfully added batch 4 to Neo4j
# Processed batch 5: [GraphDocument(nodes=[], relationships=[], source=Document(metadata={'chunk_id': 4, 'source': 'resume2.pdf', 'page_number': 0, 'total_length': 297, 'text_preview': "UniversityofOttawa September2021-December2025\nBachelor's,ComputerScience GPA:3.8/4.0\n• RelevantCours...", 'embedding': [-0.005850563291460276, -0.020291827619075775, 0.01786811836063862, -0.037082742899656296, -0.006749355234205723, 0.021045871078968048, -0.026378029957413673, -0.00401258422061801, -0.03829459846019745, -0.02310602180659771, 0.020466873422265053, 0.001809365814551711, 0.006267979741096497, -0.001829563407227397, 0.02043994329869747, -0.02038608305156231, 0.002228465396910906, -0.017154471948742867, 0.013424652628600597, -0.00110413390211761, -0.008873466402292252, -0.0014862046809867024, -0.010388284921646118, -0.0172487273812294, -0.009102372452616692, -0.010704712942242622, -0.015686780214309692, -0.022904047742486, 0.022351980209350586, -0.017329517751932144, 0.035493865609169006, -0.013660291209816933, -0.03086188994348049, -0.012057950720191002, -0.029542315751314163, -0.0086243636906147, -0.007749135140329599, -0.001083094859495759, 0.007432706654071808, 0.015781035646796227, 0.04125690832734108, 0.03215453401207924, 0.0046690055169165134, 0.018891463056206703, 0.00037344469456002116, 0.011647266335785389, -0.005965016316622496, -0.014017115347087383, -0.0344974547624588, 0.032262254506349564, -0.010819165967404842, 0.03261234611272812, -0.0071499403566122055, -0.01248209923505783, 0.008839803747832775, 0.009997798129916191, 0.0031205248087644577, 0.017854653298854828, -0.0316428616642952, -0.023658089339733124, 0.00737211387604475, -0.0034504185896366835, -0.026849305257201195, -0.004426634404808283, -0.020709244534373283, 0.031615931540727615, -0.031858302652835846, 0.029569245874881744, 0.0012741301907226443, 0.007547159679234028, 0.013431385159492493, 0.027482163161039352, 0.0005154588725417852, -0.0042515890672802925, 0.041176117956638336, -0.004722865764051676, -0.018635626882314682, 0.004729598294943571, 0.00792418047785759, 0.003019537078216672, -0.0020399547647684813, -0.032289184629917145, 0.004628610331565142, -0.009580382145941257, 0.004342478234320879, 0.019430063664913177, -0.0011117079993709922, 0.007513497024774551, -0.012549424543976784, -0.03059258870780468, 0.02293097786605358, 0.026351099833846092, 0.02149021625518799, 0.008193481713533401, -0.030538728460669518, 0.00607273681089282, -0.027791859582066536, 0.03557465597987175, 0.00012202699872432277, -0.025475870817899704, -0.014838483184576035, 0.015956081449985504, -0.013653558678925037, -0.015794500708580017, -0.03740590438246727, -0.011633801274001598, -0.02719939686357975, -0.008092493750154972, 0.029488455504179, 0.0051907761953771114, -0.0027519192080944777, 0.051598064601421356, 0.007271125912666321, -0.03495526686310768, -0.018649091944098473, -0.004500692244619131, 0.0017176351975649595, -0.0068099480122327805, -0.0031895332504063845, -0.018891463056206703, 0.026149123907089233, 0.018218209967017174, 0.01811048947274685, -0.010798968374729156, 0.03829459846019745, 0.02240584045648575, -0.00607273681089282, -0.011680928990244865, 0.04015277326107025, -0.002581923035904765, 0.00918989535421133, 0.0018699585925787687, 0.007957843132317066, -0.0015265998663380742, -0.013357327319681644, 0.01677745021879673, -0.020520733669400215, -0.003783678635954857, -0.03290857747197151, -0.024115901440382004, 0.008732084184885025, 0.02380620501935482, -0.015727175399661064, 0.004692569375038147, -0.0031895332504063845, 0.013518908061087132, 0.02738790772855282, -0.0020113415084779263, 0.012744667939841747, 0.026122193783521652, -0.0013111591106280684, 0.007742402609437704, -0.0022957907058298588, 0.022742467001080513, -0.005493739619851112, -0.04572730511426926, 0.013370792381465435, 0.03603246808052063, 0.0034016077406704426, -0.012535959482192993, -0.017854653298854828, 0.013815139420330524, -0.009021582081913948, -0.024412132799625397, -0.01320921257138252 ...
# Successfully added batch 5 to Neo4j

# %% [markdown]
# ### Query Functions

# %%
query = "where were the hackathons? by abi kakolla?"
vector_retriever.search_kwargs = {"k": 1} # change k value later (depends on length of context)
results = vector_retriever.invoke(query)

# print(len(results))
for doc in results:
    print(doc.id)
    print("source: " + doc.metadata['source'])
    print("page number: " + str(doc.metadata['page_number']))
    print(doc.page_content)

# print(results[0].metadata['text_preview'])
# Out:
# None
# source: resume.pdf
# page number: 0
#
# text: Abi Kakolla
# Toronto, ON | 647-957-7403 | kakolla@usc.edu | linkedin.com/in/kakolla | kakolla.com
# Education
# University of Southern California Los Angeles, CA
# Bachelor of Science in Computer Science (GPA: 3.71) Aug 2023 – Dec 2026
# Hackathons: HackHarvard (Harvard), LAHacks (UCLA), HackSC (USC), CalHacks (Berkeley)
# Experience
# Machine Learning Researcher Aug 2023 – Present
# USC Center for Neural Engineering Los Angeles, CA
# • Modeled in-silico layers of the Hippocampus used to generate a dendritic tree as part of a neural network using
# MeshLab and Python
# • Developed open-source software to grid a dataset of 6 million neural points that enhanced the neural mesh model
# resolution by 348%, enabling other teams to create more accurate models and save on computational costs
# • Reduced neural network generation by 75% by integrating unsupervised machine learning algorithms, enabling
# faster simulations

# %% [markdown]
# ### Use retrieved chunk to query for subgraph around

# %%
retrieved_text_preview = results[0].metadata['text_preview']

prompt_query = """
MATCH (x)<-[r]-(p)-[]-(d:Document)
WHERE d.text_preview = \"""" + retrieved_text_preview + """\" AND NOT p:Document AND NOT x:Document
RETURN {id: p.id} AS Concept1, 
  {type: type(r)} AS Relationship, 
  {id: x.id} AS Concept2
"""
graph.query(prompt_query)
# Out:
# [{'Concept1': {'id': 'Machine Learning Researcher'},
#   'Relationship': {'type': 'WORKS_AT'},
#   'Concept2': {'id': 'USC Center for Neural Engineering'}},
#  {'Concept1': {'id': 'Abi Kakolla'},
#   'Relationship': {'type': 'WORKS_AS'},
#   'Concept2': {'id': 'Machine Learning Researcher'}},
#  {'Concept1': {'id': 'Abi Kakolla'},
#   'Relationship': {'type': 'EDUCATION_AT'},
#   'Concept2': {'id': 'University of Southern California'}}]

# %%
# import openai
# from langchain.prompts import ChatPromptTemplate
# from langchain.llms import OpenAI
# from pydantic import BaseModel, Field
# from langchain.chains import LLMChain

# # Define a prompt to extract entities from the input query
# prompt = ChatPromptTemplate.from_messages([ 
#     ("system", "Extract concepts and idea entities from the text."),
#     ("human", "Extract entities from: {question}")
# ])
# # Initialize the OpenAI model for entity extraction
# llm = ChatOpenAI(model="gpt-3.5-turbo")  

# # Combine the prompt and OpenAI model to create an entity extraction chain
# entity_chain = LLMChain(prompt=prompt, llm=llm)
# def graph_retriever(question: str) -> str:
#     global entity_chain
#     # Define a model for the extracted entities from the text
#     class Entities(BaseModel):
#         names: list[str] = Field(..., description="All entities from the text")

    


#     # Use the entity extraction chain to get entities from the question
#     response = entity_chain.run({"question": question})

#     # Assuming response is structured as {'names': ['Person A', 'Organization B']}
#     entities = response.get("names", [])
#     print("Retrieved Entities:")
#     print(entities)
    
#     result = ""  # Initialize a variable to store the result

#     # Iterate over each extracted entity and query Neo4j for relationships
#     for entity in entities:
#         query_response = graph.query(
#             """MATCH (p:__Entity__ {id: $entity})-[r]->(e)
#             RETURN p.id AS source_id, type(r) AS relationship, e.id AS target_id
#             LIMIT 50""",
#             {"entity": entity}
#         )
#         # Format the query results and append to the result string
#         result += "\n".join([f"{el['source_id']} - {el['relationship']} -> {el['target_id']}" for el in query_response])

#     # Return the formatted results containing entity relationships
#     return result
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_24788\2915115492.py:16: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   entity_chain = LLMChain(prompt=prompt, llm=llm)

# %%
# from langchain_core.runnables import RunnablePassthrough
# from langchain_core.output_parsers import StrOutputParser

# from langchain.chat_models import ChatOpenAI

# def querying_ollama(question):
#     global entity_chain
#     # Define a function that combines data retrieved from both Neo4j and vector embeddings
#     def full_retriever(question: str):
#         # Retrieve graph data for the question using the graph_retriever function
#         graph_data = graph_retriever(question)
#         print("Graph Data")
#         print(graph_data)
        
#         # Retrieve vector data by invoking the vector retriever with the question
#         vector_data = [el.page_content for el in vector_retriever.invoke(question)]
        
#         # Combine the graph data and vector data into a formatted string
#         return f"Graph data: {graph_data}\nVector data: {'#Document '.join(vector_data)}"

#     # Define a prompt template for generating a response based on context
#     template = """Answer the question based only on the following context:
#     {context}
#     Question: {question}
#     Answer:"""
    
#     # Create a prompt from the template, which takes the context and question as input
#     prompt = ChatPromptTemplate.from_template(template)
    
#     # Initialize the ChatOpenAI model (you can use your preferred model here)
#     llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)  # Use ChatOpenAI for chat models

#     # Create a processing chain that:
#     # 1. Generates context using the full_retriever function
#     # 2. Passes through the question as-is using RunnablePassthrough
#     # 3. Applies the prompt template to generate the final question
#     # 4. Uses the LLM (language model) to generate the answer
#     # 5. Uses StrOutputParser to format the output as a string
#     chain = (
#         {
#             "context": lambda input: full_retriever(input),  # Generate context from the question
#             "question": RunnablePassthrough(),  # Pass the question through without modification
#         }
#         | prompt  # Apply the prompt template
#         | llm  # Use the language model to answer the question based on context
#         | StrOutputParser()  # Parse the model's response as a string
#     )

#     # Call the chain to get the response
#     import json

#     response = entity_chain.run({"question": question})
#     print(response)
#     try:
#         response_json = json.loads(response)  # Convert string to dictionary
#         print(response)
#         entities = response_json.get("names", [])  # Now we can safely use .get()
#     except json.JSONDecodeError:
#         entities = []  # Handle the case where the response isn't valid JSON

#     print("Retrieved Entities:")
#     print(entities)

# %% [markdown]
# ### Test

# %%
# querying_ollama("Explain the tools and technologies in the resume")
# Out:
# Entities:
# - Tools
# - Technologies
# - Resume
# Retrieved Entities:
# []
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
