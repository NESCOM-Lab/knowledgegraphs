# %%
# %pip --quiet install --upgrade neo4j langchain-community
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Neo4j setup

# %%
# from langchain_community.graphs import Neo4jGraph
from langchain_neo4j import Neo4jGraph
from dotenv import load_dotenv
import os
# from langchain.graphs.neo4j_graph import Neo4jGraph 
# from langchain.chains import GraphQAChain old
from langchain_neo4j import GraphCypherQAChain

from langchain_core.prompts import PromptTemplate
# from langchain_community.chains.graph_qa.cypher import GraphCypherQAChain

load_dotenv()
neo_pass = os.getenv("NEO4J_PASS")
neo_db_id = os.getenv("DB_ID")

graph = Neo4jGraph(
    url="neo4j+s://f5c81351.databases.neo4j.io",
    username="neo4j",
    password=neo_pass,
    enhanced_schema=True
    # refresh_schema=Fa lse
)

def clean_graph():
    query = """
    MATCH (n)
    DETACH DELETE n
    """
    graph.query(query)

# %% [markdown]
# ### OpenAI setup

# %%
import getpass
import os
from dotenv import load_dotenv

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")
# os.environ[api_key] = getpass.getpass()
import os
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Neo4jVector

llm = ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")

additional_instructions = """
When creating entities, add a "document_id" property to each node and set it to the document's unique ID.
For example, if the document ID is "doc123", each created node should include document_id: "doc123".
Query example: 
CREATE (n:NodeLabel) 
SET n.document_id = "doc123" 
RETURN n
"""
llm_transformer = LLMGraphTransformer(llm=llm, additional_instructions=additional_instructions, ignore_tool_usage=True)

# Embeddings for complex search queries
embed = OpenAIEmbeddings(model="text-embedding-ada-002")
vector_index = Neo4jVector.from_existing_graph(
    embedding=embed,
    search_type="vector",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)
vector_retriever = vector_index.as_retriever()

# %% [markdown]
# ### Split document into chunks

# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

pdf_path = "testdoc.pdf"
loader = PyPDFLoader(pdf_path)
pages = loader.load_and_split()
pages = loader.load() # load pages

# chunk overlap is the shared context window between chunks--allows context to be maintained across chunks
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200, length_function=len)

splits = text_splitter.split_documents(pages) # split the pages using LangChain's text_splitter

processed_chunks = []

for i, chunk in enumerate(splits):
    # Process the chunk
    metadata = {
        "chunk_id": i,
        "source": pdf_path,
        "page_number": chunk.metadata.get("page", None),
        "total_length": len(chunk.page_content),
        "text_preview": (
            chunk.page_content[:100] + "..."
            if len(chunk.page_content) > 100
                else chunk.page_content
        ),


    }
    # Store the metadata for each chunk after processing
    processed_chunks.append({"text": chunk.page_content, "metadata": metadata})

print(str(len(processed_chunks)) + " chunks processed")
# print(processed_chunks[6]['metadata']['text_preview'])
# print(processed_chunks[6]['metadata'])
# print(processed_chunks[0]['text_preview'])
# Out:
# 10 chunks processed

# %%
# Check out processed chunks
print(processed_chunks[7]['metadata'])
# Out:
# {'chunk_id': 7, 'source': 'testdoc.pdf', 'page_number': 1, 'total_length': 997, 'text_preview': 'imaginations,\n \nconnecting\n \nreaders\n \nto\n \ndifferent\n \nworlds,\n \ncultures,\n \nand\n \ntime\n \nperiods.\n...'}

# %%
# from typing import List, Dict
# # Create graph using the processed chunks
# def create_graph(chunks: List[Dict]):
#     # cypher query to create the chunks & their attributes
#     create_chunk_query = """
#     MERGE (chunk:Chunk {chunk_id: $chunk_id})
#     ON CREATE SET
#         chunk.source = $source,
#         chunk.page_number = $page_number,
#         chunk.total_length = $total_length,
#         chunk.text_preview = $text_preview,
#         chunk.full_text = $full_text
#         RETURN chunk
#     """

#     for chunk in chunks:
#         graph.query

# %% [markdown]
# ### Parse Document (prob able to optimize this)

# %%
import asyncio
from langchain_core.documents import Document


# Convert processed chunks to Langchain Document for Neo4j db
docs = [
    Document(
        page_content=chunk['text'],
        metadata=chunk['metadata']
    )
    for chunk in processed_chunks
]

# Function to process documents in batches
async def process_batches(docs, batch_size=2, retry_delay=20, max_retries=5):
    for i in range(0, len(docs), batch_size):
        batch = docs[i : i + batch_size] # Use subset of documents
        retries = 0
        
        while retries < max_retries:
            try:
                # generate embeddings for each doc
                for doc in batch:
                    embedding = embed.embed_query(doc.page_content)
                    doc.metadata["embedding"] = embedding


                graph_docs = await llm_transformer.aconvert_to_graph_documents(batch)
                print(f"Processed batch {i // batch_size + 1}: {graph_docs}")
                
                # Add to Neo4j
                graph.add_graph_documents(graph_docs, include_source=True, baseEntityLabel=True)
                print(f"Successfully added batch {i // batch_size + 1} to Neo4j")
                break  # exit if retry works
            
            except Exception as e:
                if "rate_limit_exceeded" in str(e):
                    retries += 1
                    print(f"Rate limit hit. Retrying batch {i // batch_size + 1} in {retry_delay} seconds... (Attempt {retries}/{max_retries})")
                    await asyncio.sleep(retry_delay)
                else:
                    raise  # other error

# Run batching process
await process_batches(docs, batch_size=2)
# Out:
# Processed batch 1: [GraphDocument(nodes=[Node(id='creating a partial vacuum', type='Process', properties={}), Node(id='Vacuums', type='Product', properties={}), Node(id='vitamins', type='Nutrient', properties={}), Node(id='Apples', type='Product', properties={}), Node(id='cooking', type='Activity', properties={}), Node(id='apple juice', type='Product', properties={}), Node(id='cider', type='Product', properties={}), Node(id='particles', type='Element', properties={}), Node(id='container', type='Container', properties={}), Node(id='fiber', type='Nutrient', properties={}), Node(id='floors', type='Surface', properties={}), Node(id='air', type='Element', properties={}), Node(id='bag', type='Container', properties={}), Node(id='surfaces', type='Surface', properties={}), Node(id='applesauce', type='Product', properties={}), Node(id='apple trees', type='Plant', properties={}), Node(id='antioxidants', type='Nutrient', properties={})], relationships=[Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='apple trees', type='Plant', properties={}), type='GROWS_ON', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='vitamins', type='Nutrient', properties={}), type='CONTAINS', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='fiber', type='Nutrient', properties={}), type='CONTAINS', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='antioxidants', type='Nutrient', properties={}), type='CONTAINS', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='cooking', type='Activity', properties={}), type='USED_IN', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='apple juice', type='Product', properties={}), type='MADE_INTO', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='cider', type='Product', properties={}), type='MADE_INTO', properties={}), Relationship(source=Node(id='Apples', type='Product', properties={}), target=Node(id='applesauce', type='Product', properties={}), type='MADE_INTO', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='floors', type='Surface', properties={}), type='USED_TO_CLEAN', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='surfaces', type='Surface', properties={}), type='USED_TO_CLEAN', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='creating a partial vacuum', type='Process', properties={}), type='WORKS_BY', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='air', type='Element', properties={}), type='PULLS_IN', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='particles', type='Element', properties={}), type='PULLS_IN', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='bag', type='Container', properties={}), type='TRAPS_IN', properties={}), Relationship(source=Node(id='Vacuums', type='Product', properties={}), target=Node(id='container', type='Container', properties={}), type='TRAPS_IN', properties={})], source=Document(metadata={'chunk_id': 0, 'source': 'testdoc.pdf', 'page_number': 0, 'total_length': 999, 'text_preview': 'Apples  are  nutritious,  round  fruits  that  grow  on  apple  trees  (Malus  domestica).  They  co...', 'embedding': [-0.004197887610644102, -0.009216813370585442, 0.004363419488072395, -0.01394440233707428, 0.005068584810942411, 0.015162716619670391, -0.01041526347398758, -0.025160839781165123, 0.010262974537909031, -0.04322367534041405, 0.005806857254356146, 0.01583808660507202, -0.03893309086561203, -0.003171590156853199, -0.029371969401836395,  ...
# Successfully added batch 1 to Neo4j
# Processed batch 2: [GraphDocument(nodes=[Node(id='School buses', type='Vehicle', properties={}), Node(id='designated points', type='Location', properties={}), Node(id='students', type='Passenger', properties={}), Node(id='transporting children to and from school', type='Purpose', properties={}), Node(id='mitochondria', type='Cellular Component', properties={}), Node(id='high-backed seats', type='Safety Feature', properties={}), Node(id='flashing lights', type='Safety Feature', properties={}), Node(id='specific routes', type='Procedure', properties={}), Node(id='regulating cell growth', type='Cellular Process', properties={}), Node(id='can replicate independently of the cell', type='Characteristic', properties={}), Node(id='bright yellow', type='Color', properties={}), Node(id='large windows', type='Safety Feature', properties={}), Node(id='apoptosis (programmed cell death)', type='Cellular Process', properties={}), Node(id='controlling the cell cycle', type='Cellular Process', properties={}), Node(id='own DNA', type='Genetic Material', properties={})], relationships=[Relationship(source=Node(id='mitochondria', type='Cellular Component', properties={}), target=Node(id='regulating cell growth', type='Cellular Process', properties={}), type='INVOLVED_IN', properties={}), Relationship(source=Node(id='mitochondria', type='Cellular Component', properties={}), target=Node(id='controlling the cell cycle', type='Cellular Process', properties={}), type='INVOLVED_IN', properties={}), Relationship(source=Node(id='mitochondria', type='Cellular Component', properties={}), target=Node(id='apoptosis (programmed cell death)', type='Cellular Process', properties={}), type='INVOLVED_IN', properties={}), Relationship(source=Node(id='mitochondria', type='Cellular Component', properties={}), target=Node(id='own DNA', type='Genetic Material', properties={}), type='HAS_DNA', properties={}), Relationship(source=Node(id='mitochondria', type='Cellular Component', properties={}), target=Node(id='can replicate independently of the cell', type='Characteristic', properties={}), type='REPLICATES_INDEPENDENTLY', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='transporting children to and from school', type='Purpose', properties={}), type='DESIGNED_FOR', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='bright yellow', type='Color', properties={}), type='HAS_COLOR', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='high-backed seats', type='Safety Feature', properties={}), type='HAS_FEATURE', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='large windows', type='Safety Feature', properties={}), type='HAS_FEATURE', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='flashing lights', type='Safety Feature', properties={}), type='HAS_FEATURE', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='specific routes', type='Procedure', properties={}), type='FOLLOWS', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='designated points', type='Location', properties={}), type='STOPS_AT', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='students', type='Passenger', properties={}), type='PICKS_UP', properties={}), Relationship(source=Node(id='School buses', type='Vehicle', properties={}), target=Node(id='students', type='Passenger', properties={}), type='DROPS_OFF', properties={})], source=Document(metadata={'chunk_id': 2, 'source': 'testdoc.pdf', 'page_number': 0, 'total_length': 989, 'text_preview': 'through\n \na\n \nprocess\n \ncalled\n \ncellular\n \nrespiration.\n \nIn\n \naddition\n \nto\n \nenergy\n \nproductio ...
# Successfully added batch 2 to Neo4j
# Processed batch 3: [GraphDocument(nodes=[Node(id='type of milk', type='Characteristic', properties={}), Node(id='dairy product', type='Product', properties={}), Node(id='countless varieties', type='Characteristic', properties={}), Node(id='brie', type='Product', properties={}), Node(id='complex facilities', type='Characteristic', properties={}), Node(id='Cheese', type='Product', properties={}), Node(id='gateways for travelers and goods', type='Characteristic', properties={}), Node(id='Airports', type='Facility', properties={}), Node(id='cheddar', type='Product', properties={}), Node(id='aging process', type='Characteristic', properties={}), Node(id='mozzarella', type='Product', properties={}), Node(id='bacteria and molds added', type='Characteristic', properties={})], relationships=[Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='dairy product', type='Product', properties={}), type='MADE_BY', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='countless varieties', type='Characteristic', properties={}), type='HAS_VARIETIES', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='type of milk', type='Characteristic', properties={}), type='DEPENDS_ON', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='bacteria and molds added', type='Characteristic', properties={}), type='DEPENDS_ON', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='aging process', type='Characteristic', properties={}), type='DEPENDS_ON', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='cheddar', type='Product', properties={}), type='ENJOYED', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='brie', type='Product', properties={}), type='ENJOYED', properties={}), Relationship(source=Node(id='Cheese', type='Product', properties={}), target=Node(id='mozzarella', type='Product', properties={}), type='ENJOYED', properties={}), Relationship(source=Node(id='Airports', type='Facility', properties={}), target=Node(id='gateways for travelers and goods', type='Characteristic', properties={}), type='SERVE_AS', properties={}), Relationship(source=Node(id='Airports', type='Facility', properties={}), target=Node(id='complex facilities', type='Characteristic', properties={}), type='ARE', properties={})], source=Document(metadata={'chunk_id': 4, 'source': 'testdoc.pdf', 'page_number': 1, 'total_length': 996, 'text_preview': 'Cheese  is  a  beloved  dairy  product  made  by  coagulating  milk  proteins,  typically  through  ...', 'embedding': [-0.00033786476706154644, -0.014808468520641327, 0.0015877103433012962, -0.040536995977163315, 0.009978442452847958, 0.01560782827436924, -0.016014281660318375, -0.03975118696689606, -0.027083374559879303, -0.050752539187669754, 0.0142529821023345, 0.016989771276712418, -0.04427637159824371, 0.005124705843627453, -0.02029559575021267, 0.020945921540260315, 0.029373064637184143, -0.0034209867008030415, 0.000910287257283926, -0.038098275661468506, -0.010439089499413967, 0.005145028233528137, -0.007851333357393742, -0.02452271617949009, -0.001815493917092681, 0.012071679346263409, 0.02705627866089344, -0.02078334055840969, 0.014998147264122963, 0.00926714763045311, 0.0059647103771567345, 0.00028599955840036273, -0.02410271391272545, -0.007566815707832575, -0.028018219396471977, -0.009199405089020729, -0.023262709379196167, -0.024753039702773094, 0.003668246092274785, 0.01666460745036602, 0.015038792975246906, -0.00508067337796092, 0.00676406966522336, 0.013236846774816513, -0.005802128929644823, 0.026378855109214783, -0.0035259872674942017, -0.029860809445381165, 0.019577527418732643, 0.007214555982500315, 0.062485504895448685, 0.0051179314032197, -0.02075624279677868, -0.014835565350949764, -0.00567003106 ...
# Successfully added batch 3 to Neo4j
# Processed batch 4: [GraphDocument(nodes=[Node(id='countless genres from fiction and non-fiction to poetry, biographies, and scientific journals', type='Characteristic', properties={}), Node(id='Books', type='Product', properties={}), Node(id='their ideas, emotions, and imaginations', type='Characteristic', properties={}), Node(id='airports', type='Facility', properties={}), Node(id='modern transportation', type='Concept', properties={}), Node(id='demands of both efficiency and comfort', type='Characteristic', properties={}), Node(id='inspire, challenge, and entertain', type='Characteristic', properties={}), Node(id='different worlds, cultures, and time periods', type='Concept', properties={}), Node(id='human culture', type='Concept', properties={}), Node(id='a way to escape, learn, and experience new perspectives', type='Characteristic', properties={})], relationships=[Relationship(source=Node(id='airports', type='Facility', properties={}), target=Node(id='demands of both efficiency and comfort', type='Characteristic', properties={}), type='EVOLVED_TO_MEET', properties={}), Relationship(source=Node(id='airports', type='Facility', properties={}), target=Node(id='modern transportation', type='Concept', properties={}), type='ESSENTIAL_TO', properties={}), Relationship(source=Node(id='Books', type='Product', properties={}), target=Node(id='a way to escape, learn, and experience new perspectives', type='Characteristic', properties={}), type='OFFERS', properties={}), Relationship(source=Node(id='Books', type='Product', properties={}), target=Node(id='human culture', type='Concept', properties={}), type='CENTRAL_PART_OF', properties={}), Relationship(source=Node(id='Books', type='Product', properties={}), target=Node(id='countless genres from fiction and non-fiction to poetry, biographies, and scientific journals', type='Characteristic', properties={}), type='COME_IN_GENRES', properties={}), Relationship(source=Node(id='Books', type='Product', properties={}), target=Node(id='their ideas, emotions, and imaginations', type='Characteristic', properties={}), type='ALLOWS_AUTHORS_TO_SHARE', properties={}), Relationship(source=Node(id='Books', type='Product', properties={}), target=Node(id='different worlds, cultures, and time periods', type='Concept', properties={}), type='CONNECTS_READERS_TO', properties={}), Relationship(source=Node(id='Books', type='Product', properties={}), target=Node(id='inspire, challenge, and entertain', type='Characteristic', properties={}), type='HAS_ABILITY_TO', properties={})], source=Document(metadata={'chunk_id': 6, 'source': 'testdoc.pdf', 'page_number': 1, 'total_length': 987, 'text_preview': 'between\n \ncities\n \nand\n \ncountries.\n \nWith\n \nthe\n \nincreasing\n \nnumber\n \nof\n \ntravelers,\n \nairports\n...', 'embedding': [0.004422041587531567, -0.0022393460385501385, 0.008377552963793278, -0.006904650013893843, 0.011623271740972996, 0.015368844382464886, -0.022726695984601974, -0.028604978695511818, -0.013089509680867195, -0.04537341371178627, -0.013649346306920052, 0.02142040990293026, -0.020300736650824547, 0.007371180225163698, -0.007591116242110729, 0.01696837693452835, 0.030657712370157242, -0.00915066059678793, -0.007504474837332964, -0.017181647941470146, -0.03932184725999832, -0.0191144160926342, 0.001931102597154677, -0.0061815278604626656, -0.009117336943745613, 0.024526169523596764, 0.03231056407094002, -0.040788087993860245, 0.012216432020068169, -0.010336981154978275, 0.004718621727079153, -0.00036739269853569567, -0.032870400696992874, -0.01787477917969227, -0.029084838926792145, -0.02532593533396721, -0.023233214393258095, -0.017461566254496574, -0.004058814607560635, -0.02266004867851734, 0.027725234627723694, 0.005521720740944147, -0.017808131873607635, -0.0006231513107195497, -0.025539206340909004, 0.017728155478835106, 0.004991875495761633, -0.025925761088728905, -0.016568493098020554, 0.0047386158257722855, 0.02056732587516308, 0.03031114675104618, -0.02407296933233738, -0.041 ...
# Successfully added batch 4 to Neo4j
# Processed batch 5: [GraphDocument(nodes=[Node(id='context', type='Characteristic', properties={}), Node(id='fields', type='Concept', properties={}), Node(id='LLMs', type='Model', properties={}), Node(id='transformers', type='Architecture', properties={}), Node(id='nuances', type='Characteristic', properties={}), Node(id='coherent responses', type='Characteristic', properties={}), Node(id='important questions', type='Concept', properties={})], relationships=[Relationship(source=Node(id='LLMs', type='Model', properties={}), target=Node(id='transformers', type='Architecture', properties={}), type='BASED_ON', properties={}), Relationship(source=Node(id='LLMs', type='Model', properties={}), target=Node(id='context', type='Characteristic', properties={}), type='ANALYZE', properties={}), Relationship(source=Node(id='LLMs', type='Model', properties={}), target=Node(id='nuances', type='Characteristic', properties={}), type='RECOGNIZE', properties={}), Relationship(source=Node(id='LLMs', type='Model', properties={}), target=Node(id='coherent responses', type='Characteristic', properties={}), type='CREATE', properties={}), Relationship(source=Node(id='LLMs', type='Model', properties={}), target=Node(id='important questions', type='Concept', properties={}), type='RAISE', properties={}), Relationship(source=Node(id='LLMs', type='Model', properties={}), target=Node(id='fields', type='Concept', properties={}), type='REVOLUTIONIZED', properties={})], source=Document(metadata={'chunk_id': 8, 'source': 'testdoc.pdf', 'page_number': 1, 'total_length': 655, 'text_preview': 'answering\n \nquestions\n \nand\n \nwriting\n \nessays\n \nto\n \ntranslating\n \nlanguages\n \nand\n \ngenerating\n \nc...', 'embedding': [-0.012111900374293327, -0.014296685345470905, -0.003912130370736122, -0.026135487481951714, -5.368617712520063e-05, 0.009490159340202808, -0.02314506471157074, 0.0037789950147271156, -0.021998051553964615, -0.048420291393995285, 0.037769466638565063, 0.027364429086446762, -0.03045043721795082, -0.009599397890269756, 0.008213425055146217, 0.014788261614739895, 0.029248805716633797, 0.003526379121467471, -0.0008423369727097452, -0.0156621765345335, 0.002418624935671687, -0.026026248931884766, -0.009203406050801277, -0.03940805420279503, 0.00370389292947948, -0.009613052941858768, 0.03615818917751312, -0.03918957710266113, -0.029658453539013863, 0.00029464723775163293, 0.017191525548696518, -0.004874801263213158, -0.02438765950500965, -0.0038438558112829924, -0.004017955623567104, -0.015293493866920471, 0.012057281099259853, -0.0040281969122588634, 0.0005073650390841067, 0.007694539148360491, 0.02389608323574066, 0.017041321843862534, 0.01342959888279438, -0.01727345399558544, -0.007790123112499714, 0.020496012642979622, 0.0017188111087307334, -0.02655879035592079, -0.01787427067756653, 0.007121033035218716, 0.018912043422460556, 0.03695017099380493, -0.02370491437613964, -0.022421354427933693, -0.014487854205071926, -0.011005853302776814, 0.0003471332893241197, 0.00822708010673523, 0.015457352623343468, -0.006192499306052923, 0.002957993885502219, 0.0021421131677925587, -0.016194717958569527, 0.034628838300704956, 0.0024152114056050777, -0.016495125368237495, -0.025766804814338684, 0.037469059228897095, 0.0019663062412291765, -0.008466040715575218, -0.002186491619795561, 0.01422841101884842, -0.0025244506541639566, 0.0026678270660340786, 0.03856145218014717, -0.015416387468576431, -0.0012024850584566593, -0.03656783699989319, -0.03364568576216698, 0.003857510630041361, -0.0010446002706885338, 0.005673612933605909, -0.0010966595727950335, 0.011613496579229832, -0.004137436393648386, -0.011804665438830853, 0.005905746482312679, -0.003956508822739124, -0.014760952442884445, 0.006533871870487928, 0.0057214051485061646, 0.003239626297727227, 0.03118780255317688, 0.0290303286164999, 0.0054278247989714146, 0.0104869669303298, -0.013511528261005878, 0.0004885895759798586, 0.0015378836542367935, -0.02463344857096672, 0.004635840188711882, 0.009339954 ...
# Successfully added batch 5 to Neo4j

# %% [markdown]
# ### Query Functions

# %%
query = "what is chatgpt"
vector_retriever.search_kwargs = {"k": 1} # change k value later (depends on length of context)
results = vector_retriever.get_relevant_documents(query)

print(len(results))
for doc in results:
    print(doc.id)
    print("page number: " + str(doc.metadata['page_number']))
    print(doc.page_content)
# Out:
# 1
# None
# page number: 1
#
# text: answering
#
# questions
#
# and
#
# writing
#
# essays
#
# to
#
# translating
#
# languages
#
# and
#
# generating
#
# code.
#
# LLMs,
#
# like
#
# GPT-4,
#
# are
#
# based
#
# on
#
# deep
#
# learning
#
# architectures
#
# known
#
# as
#
# transformers,
#
# which
#
# allow
#
# them
#
# to
#
# analyze
#
# context,
#
# recognize
#
# nuances,
#
# and
#
# create
#
# coherent,
#
# contextually
#
# relevant
#
# responses.
#
# While
#
# LLMs
#
# are
#
# incredibly
#
# powerful,
#
# their
#
# capabilities
#
# are
#
# still
#
# evolving,
#
# and
#
# they
#
# raise
#
# important
#
# questions
#
# about
#
# ethics,
#
# bias,
#
# and
#
# the
#
# future
#
# of
#
# human-computer
#
# interaction.
#
# These
#
# models
#
# have
#
# revolutionized
#
# fields
#
# such
#
# as
#
# natural
#
# language

# %%
import openai
from langchain.prompts import ChatPromptTemplate
from langchain.llms import OpenAI
from pydantic import BaseModel, Field
from langchain.chains import LLMChain

# Define a prompt to extract entities from the input query
prompt = ChatPromptTemplate.from_messages([ 
    ("system", "Extract concepts and idea entities from the text."),
    ("human", "Extract entities from: {question}")
])
# Initialize the OpenAI model for entity extraction
llm = ChatOpenAI(model="gpt-3.5-turbo")  

# Combine the prompt and OpenAI model to create an entity extraction chain
entity_chain = LLMChain(prompt=prompt, llm=llm)
def graph_retriever(question: str) -> str:
    global entity_chain
    # Define a model for the extracted entities from the text
    class Entities(BaseModel):
        names: list[str] = Field(..., description="All entities from the text")

    


    # Use the entity extraction chain to get entities from the question
    response = entity_chain.run({"question": question})

    # Assuming response is structured as {'names': ['Person A', 'Organization B']}
    entities = response.get("names", [])
    print("Retrieved Entities:")
    print(entities)
    
    result = ""  # Initialize a variable to store the result

    # Iterate over each extracted entity and query Neo4j for relationships
    for entity in entities:
        query_response = graph.query(
            """MATCH (p:__Entity__ {id: $entity})-[r]->(e)
            RETURN p.id AS source_id, type(r) AS relationship, e.id AS target_id
            LIMIT 50""",
            {"entity": entity}
        )
        # Format the query results and append to the result string
        result += "\n".join([f"{el['source_id']} - {el['relationship']} -> {el['target_id']}" for el in query_response])

    # Return the formatted results containing entity relationships
    return result
# Out:
# C:\Users\abhis\AppData\Local\Temp\ipykernel_24788\2915115492.py:16: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   entity_chain = LLMChain(prompt=prompt, llm=llm)

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

from langchain.chat_models import ChatOpenAI

def querying_ollama(question):
    global entity_chain
    # Define a function that combines data retrieved from both Neo4j and vector embeddings
    def full_retriever(question: str):
        # Retrieve graph data for the question using the graph_retriever function
        graph_data = graph_retriever(question)
        print("Graph Data")
        print(graph_data)
        
        # Retrieve vector data by invoking the vector retriever with the question
        vector_data = [el.page_content for el in vector_retriever.invoke(question)]
        
        # Combine the graph data and vector data into a formatted string
        return f"Graph data: {graph_data}\nVector data: {'#Document '.join(vector_data)}"

    # Define a prompt template for generating a response based on context
    template = """Answer the question based only on the following context:
    {context}
    Question: {question}
    Answer:"""
    
    # Create a prompt from the template, which takes the context and question as input
    prompt = ChatPromptTemplate.from_template(template)
    
    # Initialize the ChatOpenAI model (you can use your preferred model here)
    llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)  # Use ChatOpenAI for chat models

    # Create a processing chain that:
    # 1. Generates context using the full_retriever function
    # 2. Passes through the question as-is using RunnablePassthrough
    # 3. Applies the prompt template to generate the final question
    # 4. Uses the LLM (language model) to generate the answer
    # 5. Uses StrOutputParser to format the output as a string
    chain = (
        {
            "context": lambda input: full_retriever(input),  # Generate context from the question
            "question": RunnablePassthrough(),  # Pass the question through without modification
        }
        | prompt  # Apply the prompt template
        | llm  # Use the language model to answer the question based on context
        | StrOutputParser()  # Parse the model's response as a string
    )

    # Call the chain to get the response
    import json

    response = entity_chain.run({"question": question})
    print(response)
    try:
        response_json = json.loads(response)  # Convert string to dictionary
        print(response)
        entities = response_json.get("names", [])  # Now we can safely use .get()
    except json.JSONDecodeError:
        entities = []  # Handle the case where the response isn't valid JSON

    print("Retrieved Entities:")
    print(entities)

# %% [markdown]
# ### Test

# %%
querying_ollama("Explain the tools and technologies in the resume")
# Out:
# Entities:
# - Tools
# - Technologies
# - Resume
# Retrieved Entities:
# []
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
